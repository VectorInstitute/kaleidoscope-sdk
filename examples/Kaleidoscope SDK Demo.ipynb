# %% [markdown]
# # Kaleidoscope SDK Demo

# %%
# Notebook Deps
from IPython.lib.pretty import pretty
from pprint import pprint
import kscope

# %% [markdown]
# ## Overview
#
# In this demo, we will explore an **experimental** workflow for fine-tuning models on top of activations retreived from foundational models hosted on the Vector cluster. We will briefly demonstrate a few fundamental concepts in the following sections:
#
# * Text generation
# * Model querying and activation generation
# * Fine-tuning
#
# We will be interfacing with a deployment of the Open Pre-trained Transformers (OPT). This demonstration will utilize the OPT-175B parameter model.

# %% [markdown]
# ## Text Generation
#
#
# The Vector Kaleidoscope (kscope) Client class will be our primary tool for loading and querying the large models.
#
# ### Client Initialization

# %%
GATEWAY_HOST = "llm.cluster.local"
GATEWAY_PORT = 3001

# %%
client = kscope.Client(gateway_host=GATEWAY_HOST, gateway_port=GATEWAY_PORT)

# %% [markdown]
# The client provides a set of functions for loading and launching models on the Vector cluster. We can query the available models with the ``models`` property.

# %%
client.models
# Out:
# ['OPT-175B']

# %% [markdown]
# We can view the model instances that are currently running on the cluster via the ``model_instances`` property.

# %%
client.model_instances
# Out:
# [{'id': 'b827ad94-eee5-4166-977f-4c3b22bb0373',
#   'name': 'OPT-175B',
#   'state': 'ACTIVE'}]

# %% [markdown]
# We can obtain a handle to a given model with the ``load_model`` function. If no model instances are currently available, ``model_instances`` will return an empty list.

# %%
opt_model = client.load_model("OPT-175B")

# %% [markdown]
# You can monitor the deployment of a model instance using the ``state`` attribute. Model instances can take the following states:
#
# * **PENDING**: Waiting to send job to Vector SLURM.
# * **LAUNCHING**: Job accepted by Vector SLURM, waiting for job to run.
# * **LOADING**: SLURM job running, waiting for model to load and initialize.
# * **ACTIVE**: Ready for requests.
#
# We can verify the model state:

# %%
opt_model.state
# Out:
# 'ACTIVE'

# %% [markdown]
# And we can perform our first generation:

# %%
prompt = "Hello World"
response = opt_model.generate(prompt)

print("Prompt: ", prompt)
print("Generation: ", response.generation["text"])
# Out:
# Prompt:  Hello World
# Generation:  !
#
# Menu
#
# Tag Archives: gluten free
#
# There’s been such cool variation in the #sixsistersstampin projects I

# %% [markdown]
# We can also modify the generation hyper-parameters:

# %%
response = opt_model.generate(prompt, {"temperature": 0.9})

print("Prompt: ", prompt)
print("Generation: ", response.generation["text"])
# Out:
# Prompt:  Hello World
# Generation:  : The Journal of PHP
#
# Hello World: The Journal of PHP is a peer-reviewed open-access academic journal published by The PHP Association, covering research

# %% [markdown]
# ## Activation Generation

# %% [markdown]
# Activation generation is also quite easy. We can use the model object to query the remote model and explore the various modules.

# %%
opt_model.module_names
# Out:
# ['_fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder',
#  '_fsdp_wrapped_module._fpw_module.decoder.embed_tokens',
#  '_fsdp_wrapped_module._fpw_module.decoder.embed_positions',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.0._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.1._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.2._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.3._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.4._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.5._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.6._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.7._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.8._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.9._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.10._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.11._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.12._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.13._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.14._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.15._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.16._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.17._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.18._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.19._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.20._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.21._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.22._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.23._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.24._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.25._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.26._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.27._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.28._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.29._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.30._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.31._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.32._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.33._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.34._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.35._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.36._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.37._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.38._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.39._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.40._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.41._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
# ...
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.68._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.69._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.70._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.71._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.72._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.73._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.74._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.75._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.76._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.77._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.78._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.79._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.80._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.fc1',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.fc2',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.81._fsdp_wrapped_module._fpw_module.final_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.self_attn',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.self_attn.dropout_module',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.self_attn.qkv_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.self_attn.out_proj',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.self_attn_layer_norm',
#  '_fsdp_wrapped_module._fpw_module.decoder.layers.82._fsdp_wrapped_module._fpw_module.fc1',
#  ...]

# %% [markdown]
# We can select the module names of interest and pass them into a ``get_activations`` function alongside our set of prompts.

# %%
module_names = ['_fsdp_wrapped_module._fpw_module.decoder']

response = opt_model.get_activations(prompt, module_names)

print("Prompt: ", prompt)
print("Activations: ", response.activations)
# Out:
# Prompt:  Hello World
# Activations:  {'_fsdp_wrapped_module._fpw_module.decoder': tensor([[-7.3906, -7.4141, -0.4392,  ..., -7.9883, -7.4492, -7.6133],
#         [-6.4844, -7.0078,  6.0352,  ..., -7.5820, -7.5000, -7.9141]],
#        dtype=torch.float16)}

# %% [markdown]
# Module activations are returned as torch tensors. We can access them through the activations object:

# %%
response.activations['_fsdp_wrapped_module._fpw_module.decoder']
# Out:
# tensor([[-7.3906, -7.4141, -0.4392,  ..., -7.9883, -7.4492, -7.6133],
#         [-6.4844, -7.0078,  6.0352,  ..., -7.5820, -7.5000, -7.9141]],
#        dtype=torch.float16)

# %%
response.activations['_fsdp_wrapped_module._fpw_module.decoder'].shape
# Out:
# torch.Size([2, 50272])
