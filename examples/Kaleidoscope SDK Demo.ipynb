# %% [markdown]
# # Kaleidoscope SDK Demo

# %%
# Notebook Deps
from IPython.lib.pretty import pretty
from pprint import pprint
import kscope

# %% [markdown]
# ## Overview
#
# In this demo, we will explore an **experimental** workflow for fine-tuning models on top of activations retreived from foundational models hosted on the Vector cluster. We will briefly demonstrate a few fundamental concepts in the following sections:
#
# * Text generation
# * Model querying and activation generation
# * Fine-tuning
#
# We will be interfacing with a deployment of the Open Pre-trained Transformers (OPT). This demonstration will utilize the OPT-175B parameter model.

# %% [markdown]
# ## Text Generation
#
#
# The Vector Kaleidoscope (kscope) Client class will be our primary tool for loading and querying the large models.
#
# ### Client Initialization

# %%
GATEWAY_HOST = "llm.cluster.local"
GATEWAY_PORT = 3001

# %%
client = kscope.Client(gateway_host=GATEWAY_HOST, gateway_port=GATEWAY_PORT)

# %% [markdown]
# The client provides a set of functions for loading and launching models on the Vector cluster. We can query the available models with the ``models`` property.

# %%
client.models
# Out:
# ['gpt2', 'opt-6.7b', 'opt-175b', 'falcon-7b', 'falcon-40b', 'gptj']

# %% [markdown]
# We can view the model instances that are currently running on the cluster via the ``model_instances`` property.

# %%
client.model_instances
# Out:
# [{'id': '22f7287b-a198-447d-b1f8-ab97f6cff026',
#   'name': 'falcon-40b',
#   'state': 'LOADING'},
#  {'id': 'e91f661a-d57e-4d66-ac7d-0931a8cb2dff',
#   'name': 'opt-175b',
#   'state': 'ACTIVE'}]

# %% [markdown]
# We can obtain a handle to a given model with the ``load_model`` function. If no model instances are currently available, ``model_instances`` will return an empty list.

# %%
opt_model = client.load_model("opt-175b")

# %% [markdown]
# You can monitor the deployment of a model instance using the ``state`` attribute. Model instances can take the following states:
#
# * **PENDING**: Waiting to send job to Vector SLURM.
# * **LAUNCHING**: Job accepted by Vector SLURM, waiting for job to run.
# * **LOADING**: SLURM job running, waiting for model to load and initialize.
# * **ACTIVE**: Ready for requests.
#
# We can verify the model state:

# %%
opt_model.state
# Out:
# 'ACTIVE'

# %% [markdown]
# And we can perform our first generation:

# %%
prompt = "Hello World"
response = opt_model.generate(prompt)

print("Prompt: ", prompt)
print("Generation: ", response.generation["sequences"])
# Out:
# Prompt:  Hello World
# Generation:  ['!\n\nHello! This is my first post on the WordPress platform, and I’m happy to be here.\n\nI’m new']

# %% [markdown]
# We can also modify the generation hyper-parameters:

# %%
response = opt_model.generate(prompt, {"temperature": 0.9})

print("Prompt: ", prompt)
print("Generation: ", response.generation["sequences"])
# Out:
# Prompt:  Hello World
# Generation:  ['!\n\nMy name is Andrea and I have been making jewelry for about a year. I had been collecting and making jewelry for about two years before I actually']

# %% [markdown]
# ## Activation Generation

# %% [markdown]
# Activation generation is also quite easy. We can use the model object to query the remote model and explore the various modules.

# %%
opt_model.module_names
# Out:
# ['decoder',
#  'decoder.embed_tokens',
#  'decoder.embed_positions',
#  'decoder.layers',
#  'decoder.layers.0',
#  'decoder.layers.0.dropout_module',
#  'decoder.layers.0.self_attn',
#  'decoder.layers.0.self_attn.dropout_module',
#  'decoder.layers.0.self_attn.qkv_proj',
#  'decoder.layers.0.self_attn.out_proj',
#  'decoder.layers.0.self_attn_layer_norm',
#  'decoder.layers.0.fc1',
#  'decoder.layers.0.fc2',
#  'decoder.layers.0.final_layer_norm',
#  'decoder.layers.1',
#  'decoder.layers.1.dropout_module',
#  'decoder.layers.1.self_attn',
#  'decoder.layers.1.self_attn.dropout_module',
#  'decoder.layers.1.self_attn.qkv_proj',
#  'decoder.layers.1.self_attn.out_proj',
#  'decoder.layers.1.self_attn_layer_norm',
#  'decoder.layers.1.fc1',
#  'decoder.layers.1.fc2',
#  'decoder.layers.1.final_layer_norm',
#  'decoder.layers.2',
#  'decoder.layers.2.dropout_module',
#  'decoder.layers.2.self_attn',
#  'decoder.layers.2.self_attn.dropout_module',
#  'decoder.layers.2.self_attn.qkv_proj',
#  'decoder.layers.2.self_attn.out_proj',
#  'decoder.layers.2.self_attn_layer_norm',
#  'decoder.layers.2.fc1',
#  'decoder.layers.2.fc2',
#  'decoder.layers.2.final_layer_norm',
#  'decoder.layers.3',
#  'decoder.layers.3.dropout_module',
#  'decoder.layers.3.self_attn',
#  'decoder.layers.3.self_attn.dropout_module',
#  'decoder.layers.3.self_attn.qkv_proj',
#  'decoder.layers.3.self_attn.out_proj',
#  'decoder.layers.3.self_attn_layer_norm',
#  'decoder.layers.3.fc1',
#  'decoder.layers.3.fc2',
#  'decoder.layers.3.final_layer_norm',
#  'decoder.layers.4',
#  'decoder.layers.4.dropout_module',
#  'decoder.layers.4.self_attn',
#  'decoder.layers.4.self_attn.dropout_module',
#  'decoder.layers.4.self_attn.qkv_proj',
#  'decoder.layers.4.self_attn.out_proj',
#  'decoder.layers.4.self_attn_layer_norm',
#  'decoder.layers.4.fc1',
#  'decoder.layers.4.fc2',
#  'decoder.layers.4.final_layer_norm',
#  'decoder.layers.5',
#  'decoder.layers.5.dropout_module',
#  'decoder.layers.5.self_attn',
#  'decoder.layers.5.self_attn.dropout_module',
#  'decoder.layers.5.self_attn.qkv_proj',
#  'decoder.layers.5.self_attn.out_proj',
#  'decoder.layers.5.self_attn_layer_norm',
#  'decoder.layers.5.fc1',
#  'decoder.layers.5.fc2',
#  'decoder.layers.5.final_layer_norm',
#  'decoder.layers.6',
#  'decoder.layers.6.dropout_module',
#  'decoder.layers.6.self_attn',
#  'decoder.layers.6.self_attn.dropout_module',
#  'decoder.layers.6.self_attn.qkv_proj',
#  'decoder.layers.6.self_attn.out_proj',
#  'decoder.layers.6.self_attn_layer_norm',
#  'decoder.layers.6.fc1',
#  'decoder.layers.6.fc2',
#  'decoder.layers.6.final_layer_norm',
#  'decoder.layers.7',
#  'decoder.layers.7.dropout_module',
#  'decoder.layers.7.self_attn',
#  'decoder.layers.7.self_attn.dropout_module',
#  'decoder.layers.7.self_attn.qkv_proj',
#  'decoder.layers.7.self_attn.out_proj',
#  'decoder.layers.7.self_attn_layer_norm',
#  'decoder.layers.7.fc1',
#  'decoder.layers.7.fc2',
#  'decoder.layers.7.final_layer_norm',
#  'decoder.layers.8',
#  'decoder.layers.8.dropout_module',
#  'decoder.layers.8.self_attn',
#  'decoder.layers.8.self_attn.dropout_module',
#  'decoder.layers.8.self_attn.qkv_proj',
#  'decoder.layers.8.self_attn.out_proj',
#  'decoder.layers.8.self_attn_layer_norm',
#  'decoder.layers.8.fc1',
#  'decoder.layers.8.fc2',
#  'decoder.layers.8.final_layer_norm',
#  'decoder.layers.9',
#  'decoder.layers.9.dropout_module',
#  'decoder.layers.9.self_attn',
#  'decoder.layers.9.self_attn.dropout_module',
#  'decoder.layers.9.self_attn.qkv_proj',
#  'decoder.layers.9.self_attn.out_proj',
#  'decoder.layers.9.self_attn_layer_norm',
#  'decoder.layers.9.fc1',
#  'decoder.layers.9.fc2',
#  'decoder.layers.9.final_layer_norm',
#  'decoder.layers.10',
#  'decoder.layers.10.dropout_module',
#  'decoder.layers.10.self_attn',
#  'decoder.layers.10.self_attn.dropout_module',
#  'decoder.layers.10.self_attn.qkv_proj',
#  'decoder.layers.10.self_attn.out_proj',
#  'decoder.layers.10.self_attn_layer_norm',
#  'decoder.layers.10.fc1',
#  'decoder.layers.10.fc2',
#  'decoder.layers.10.final_layer_norm',
#  'decoder.layers.11',
#  'decoder.layers.11.dropout_module',
#  'decoder.layers.11.self_attn',
#  'decoder.layers.11.self_attn.dropout_module',
#  'decoder.layers.11.self_attn.qkv_proj',
#  'decoder.layers.11.self_attn.out_proj',
#  'decoder.layers.11.self_attn_layer_norm',
#  'decoder.layers.11.fc1',
#  'decoder.layers.11.fc2',
#  'decoder.layers.11.final_layer_norm',
#  'decoder.layers.12',
#  'decoder.layers.12.dropout_module',
#  'decoder.layers.12.self_attn',
#  'decoder.layers.12.self_attn.dropout_module',
#  'decoder.layers.12.self_attn.qkv_proj',
#  'decoder.layers.12.self_attn.out_proj',
#  'decoder.layers.12.self_attn_layer_norm',
#  'decoder.layers.12.fc1',
#  'decoder.layers.12.fc2',
#  'decoder.layers.12.final_layer_norm',
#  'decoder.layers.13',
#  'decoder.layers.13.dropout_module',
#  'decoder.layers.13.self_attn',
#  'decoder.layers.13.self_attn.dropout_module',
#  'decoder.layers.13.self_attn.qkv_proj',
#  'decoder.layers.13.self_attn.out_proj',
#  'decoder.layers.13.self_attn_layer_norm',
#  'decoder.layers.13.fc1',
#  'decoder.layers.13.fc2',
#  'decoder.layers.13.final_layer_norm',
#  'decoder.layers.14',
#  'decoder.layers.14.dropout_module',
#  'decoder.layers.14.self_attn',
#  'decoder.layers.14.self_attn.dropout_module',
#  'decoder.layers.14.self_attn.qkv_proj',
#  'decoder.layers.14.self_attn.out_proj',
#  'decoder.layers.14.self_attn_layer_norm',
#  'decoder.layers.14.fc1',
#  'decoder.layers.14.fc2',
#  'decoder.layers.14.final_layer_norm',
#  'decoder.layers.15',
#  'decoder.layers.15.dropout_module',
#  'decoder.layers.15.self_attn',
#  'decoder.layers.15.self_attn.dropout_module',
#  'decoder.layers.15.self_attn.qkv_proj',
#  'decoder.layers.15.self_attn.out_proj',
#  'decoder.layers.15.self_attn_layer_norm',
#  'decoder.layers.15.fc1',
#  'decoder.layers.15.fc2',
#  'decoder.layers.15.final_layer_norm',
#  'decoder.layers.16',
#  'decoder.layers.16.dropout_module',
#  'decoder.layers.16.self_attn',
#  'decoder.layers.16.self_attn.dropout_module',
#  'decoder.layers.16.self_attn.qkv_proj',
#  'decoder.layers.16.self_attn.out_proj',
#  'decoder.layers.16.self_attn_layer_norm',
#  'decoder.layers.16.fc1',
#  'decoder.layers.16.fc2',
#  'decoder.layers.16.final_layer_norm',
#  'decoder.layers.17',
#  'decoder.layers.17.dropout_module',
#  'decoder.layers.17.self_attn',
#  'decoder.layers.17.self_attn.dropout_module',
#  'decoder.layers.17.self_attn.qkv_proj',
#  'decoder.layers.17.self_attn.out_proj',
#  'decoder.layers.17.self_attn_layer_norm',
#  'decoder.layers.17.fc1',
#  'decoder.layers.17.fc2',
#  'decoder.layers.17.final_layer_norm',
#  'decoder.layers.18',
#  'decoder.layers.18.dropout_module',
#  'decoder.layers.18.self_attn',
#  'decoder.layers.18.self_attn.dropout_module',
#  'decoder.layers.18.self_attn.qkv_proj',
#  'decoder.layers.18.self_attn.out_proj',
#  'decoder.layers.18.self_attn_layer_norm',
#  'decoder.layers.18.fc1',
#  'decoder.layers.18.fc2',
#  'decoder.layers.18.final_layer_norm',
#  'decoder.layers.19',
#  'decoder.layers.19.dropout_module',
#  'decoder.layers.19.self_attn',
#  'decoder.layers.19.self_attn.dropout_module',
#  'decoder.layers.19.self_attn.qkv_proj',
#  'decoder.layers.19.self_attn.out_proj',
#  'decoder.layers.19.self_attn_layer_norm',
#  'decoder.layers.19.fc1',
#  'decoder.layers.19.fc2',
#  'decoder.layers.19.final_layer_norm',
#  'decoder.layers.20',
#  'decoder.layers.20.dropout_module',
#  'decoder.layers.20.self_attn',
#  'decoder.layers.20.self_attn.dropout_module',
#  'decoder.layers.20.self_attn.qkv_proj',
#  'decoder.layers.20.self_attn.out_proj',
#  'decoder.layers.20.self_attn_layer_norm',
#  'decoder.layers.20.fc1',
#  'decoder.layers.20.fc2',
#  'decoder.layers.20.final_layer_norm',
#  'decoder.layers.21',
#  'decoder.layers.21.dropout_module',
#  'decoder.layers.21.self_attn',
#  'decoder.layers.21.self_attn.dropout_module',
#  'decoder.layers.21.self_attn.qkv_proj',
#  'decoder.layers.21.self_attn.out_proj',
#  'decoder.layers.21.self_attn_layer_norm',
#  'decoder.layers.21.fc1',
#  'decoder.layers.21.fc2',
#  'decoder.layers.21.final_layer_norm',
#  'decoder.layers.22',
#  'decoder.layers.22.dropout_module',
#  'decoder.layers.22.self_attn',
#  'decoder.layers.22.self_attn.dropout_module',
#  'decoder.layers.22.self_attn.qkv_proj',
#  'decoder.layers.22.self_attn.out_proj',
#  'decoder.layers.22.self_attn_layer_norm',
#  'decoder.layers.22.fc1',
#  'decoder.layers.22.fc2',
#  'decoder.layers.22.final_layer_norm',
#  'decoder.layers.23',
#  'decoder.layers.23.dropout_module',
#  'decoder.layers.23.self_attn',
#  'decoder.layers.23.self_attn.dropout_module',
#  'decoder.layers.23.self_attn.qkv_proj',
#  'decoder.layers.23.self_attn.out_proj',
#  'decoder.layers.23.self_attn_layer_norm',
#  'decoder.layers.23.fc1',
#  'decoder.layers.23.fc2',
#  'decoder.layers.23.final_layer_norm',
#  'decoder.layers.24',
#  'decoder.layers.24.dropout_module',
#  'decoder.layers.24.self_attn',
#  'decoder.layers.24.self_attn.dropout_module',
#  'decoder.layers.24.self_attn.qkv_proj',
#  'decoder.layers.24.self_attn.out_proj',
#  'decoder.layers.24.self_attn_layer_norm',
#  'decoder.layers.24.fc1',
#  'decoder.layers.24.fc2',
#  'decoder.layers.24.final_layer_norm',
#  'decoder.layers.25',
#  'decoder.layers.25.dropout_module',
#  'decoder.layers.25.self_attn',
#  'decoder.layers.25.self_attn.dropout_module',
#  'decoder.layers.25.self_attn.qkv_proj',
#  'decoder.layers.25.self_attn.out_proj',
#  'decoder.layers.25.self_attn_layer_norm',
#  'decoder.layers.25.fc1',
#  'decoder.layers.25.fc2',
#  'decoder.layers.25.final_layer_norm',
#  'decoder.layers.26',
#  'decoder.layers.26.dropout_module',
#  'decoder.layers.26.self_attn',
#  'decoder.layers.26.self_attn.dropout_module',
#  'decoder.layers.26.self_attn.qkv_proj',
#  'decoder.layers.26.self_attn.out_proj',
#  'decoder.layers.26.self_attn_layer_norm',
#  'decoder.layers.26.fc1',
#  'decoder.layers.26.fc2',
#  'decoder.layers.26.final_layer_norm',
#  'decoder.layers.27',
#  'decoder.layers.27.dropout_module',
#  'decoder.layers.27.self_attn',
#  'decoder.layers.27.self_attn.dropout_module',
#  'decoder.layers.27.self_attn.qkv_proj',
#  'decoder.layers.27.self_attn.out_proj',
#  'decoder.layers.27.self_attn_layer_norm',
#  'decoder.layers.27.fc1',
#  'decoder.layers.27.fc2',
#  'decoder.layers.27.final_layer_norm',
#  'decoder.layers.28',
#  'decoder.layers.28.dropout_module',
#  'decoder.layers.28.self_attn',
#  'decoder.layers.28.self_attn.dropout_module',
#  'decoder.layers.28.self_attn.qkv_proj',
#  'decoder.layers.28.self_attn.out_proj',
#  'decoder.layers.28.self_attn_layer_norm',
#  'decoder.layers.28.fc1',
#  'decoder.layers.28.fc2',
#  'decoder.layers.28.final_layer_norm',
#  'decoder.layers.29',
#  'decoder.layers.29.dropout_module',
#  'decoder.layers.29.self_attn',
#  'decoder.layers.29.self_attn.dropout_module',
#  'decoder.layers.29.self_attn.qkv_proj',
#  'decoder.layers.29.self_attn.out_proj',
#  'decoder.layers.29.self_attn_layer_norm',
#  'decoder.layers.29.fc1',
#  'decoder.layers.29.fc2',
#  'decoder.layers.29.final_layer_norm',
#  'decoder.layers.30',
#  'decoder.layers.30.dropout_module',
#  'decoder.layers.30.self_attn',
#  'decoder.layers.30.self_attn.dropout_module',
#  'decoder.layers.30.self_attn.qkv_proj',
#  'decoder.layers.30.self_attn.out_proj',
#  'decoder.layers.30.self_attn_layer_norm',
#  'decoder.layers.30.fc1',
#  'decoder.layers.30.fc2',
#  'decoder.layers.30.final_layer_norm',
#  'decoder.layers.31',
#  'decoder.layers.31.dropout_module',
#  'decoder.layers.31.self_attn',
#  'decoder.layers.31.self_attn.dropout_module',
#  'decoder.layers.31.self_attn.qkv_proj',
#  'decoder.layers.31.self_attn.out_proj',
#  'decoder.layers.31.self_attn_layer_norm',
#  'decoder.layers.31.fc1',
#  'decoder.layers.31.fc2',
#  'decoder.layers.31.final_layer_norm',
#  'decoder.layers.32',
#  'decoder.layers.32.dropout_module',
#  'decoder.layers.32.self_attn',
#  'decoder.layers.32.self_attn.dropout_module',
#  'decoder.layers.32.self_attn.qkv_proj',
#  'decoder.layers.32.self_attn.out_proj',
#  'decoder.layers.32.self_attn_layer_norm',
#  'decoder.layers.32.fc1',
#  'decoder.layers.32.fc2',
#  'decoder.layers.32.final_layer_norm',
#  'decoder.layers.33',
#  'decoder.layers.33.dropout_module',
#  'decoder.layers.33.self_attn',
#  'decoder.layers.33.self_attn.dropout_module',
#  'decoder.layers.33.self_attn.qkv_proj',
#  'decoder.layers.33.self_attn.out_proj',
#  'decoder.layers.33.self_attn_layer_norm',
#  'decoder.layers.33.fc1',
#  'decoder.layers.33.fc2',
#  'decoder.layers.33.final_layer_norm',
#  'decoder.layers.34',
#  'decoder.layers.34.dropout_module',
#  'decoder.layers.34.self_attn',
#  'decoder.layers.34.self_attn.dropout_module',
#  'decoder.layers.34.self_attn.qkv_proj',
#  'decoder.layers.34.self_attn.out_proj',
#  'decoder.layers.34.self_attn_layer_norm',
#  'decoder.layers.34.fc1',
#  'decoder.layers.34.fc2',
#  'decoder.layers.34.final_layer_norm',
#  'decoder.layers.35',
#  'decoder.layers.35.dropout_module',
#  'decoder.layers.35.self_attn',
#  'decoder.layers.35.self_attn.dropout_module',
#  'decoder.layers.35.self_attn.qkv_proj',
#  'decoder.layers.35.self_attn.out_proj',
#  'decoder.layers.35.self_attn_layer_norm',
#  'decoder.layers.35.fc1',
#  'decoder.layers.35.fc2',
#  'decoder.layers.35.final_layer_norm',
#  'decoder.layers.36',
#  'decoder.layers.36.dropout_module',
#  'decoder.layers.36.self_attn',
#  'decoder.layers.36.self_attn.dropout_module',
#  'decoder.layers.36.self_attn.qkv_proj',
#  'decoder.layers.36.self_attn.out_proj',
#  'decoder.layers.36.self_attn_layer_norm',
#  'decoder.layers.36.fc1',
#  'decoder.layers.36.fc2',
#  'decoder.layers.36.final_layer_norm',
#  'decoder.layers.37',
#  'decoder.layers.37.dropout_module',
#  'decoder.layers.37.self_attn',
#  'decoder.layers.37.self_attn.dropout_module',
#  'decoder.layers.37.self_attn.qkv_proj',
#  'decoder.layers.37.self_attn.out_proj',
#  'decoder.layers.37.self_attn_layer_norm',
#  'decoder.layers.37.fc1',
#  'decoder.layers.37.fc2',
#  'decoder.layers.37.final_layer_norm',
#  'decoder.layers.38',
#  'decoder.layers.38.dropout_module',
#  'decoder.layers.38.self_attn',
#  'decoder.layers.38.self_attn.dropout_module',
#  'decoder.layers.38.self_attn.qkv_proj',
#  'decoder.layers.38.self_attn.out_proj',
#  'decoder.layers.38.self_attn_layer_norm',
#  'decoder.layers.38.fc1',
#  'decoder.layers.38.fc2',
#  'decoder.layers.38.final_layer_norm',
#  'decoder.layers.39',
#  'decoder.layers.39.dropout_module',
#  'decoder.layers.39.self_attn',
#  'decoder.layers.39.self_attn.dropout_module',
#  'decoder.layers.39.self_attn.qkv_proj',
#  'decoder.layers.39.self_attn.out_proj',
#  'decoder.layers.39.self_attn_layer_norm',
#  'decoder.layers.39.fc1',
#  'decoder.layers.39.fc2',
#  'decoder.layers.39.final_layer_norm',
#  'decoder.layers.40',
#  'decoder.layers.40.dropout_module',
#  'decoder.layers.40.self_attn',
#  'decoder.layers.40.self_attn.dropout_module',
#  'decoder.layers.40.self_attn.qkv_proj',
#  'decoder.layers.40.self_attn.out_proj',
#  'decoder.layers.40.self_attn_layer_norm',
#  'decoder.layers.40.fc1',
#  'decoder.layers.40.fc2',
#  'decoder.layers.40.final_layer_norm',
#  'decoder.layers.41',
#  'decoder.layers.41.dropout_module',
#  'decoder.layers.41.self_attn',
#  'decoder.layers.41.self_attn.dropout_module',
#  'decoder.layers.41.self_attn.qkv_proj',
#  'decoder.layers.41.self_attn.out_proj',
#  'decoder.layers.41.self_attn_layer_norm',
#  'decoder.layers.41.fc1',
#  'decoder.layers.41.fc2',
#  'decoder.layers.41.final_layer_norm',
#  'decoder.layers.42',
#  'decoder.layers.42.dropout_module',
#  'decoder.layers.42.self_attn',
#  'decoder.layers.42.self_attn.dropout_module',
#  'decoder.layers.42.self_attn.qkv_proj',
#  'decoder.layers.42.self_attn.out_proj',
#  'decoder.layers.42.self_attn_layer_norm',
#  'decoder.layers.42.fc1',
#  'decoder.layers.42.fc2',
#  'decoder.layers.42.final_layer_norm',
#  'decoder.layers.43',
#  'decoder.layers.43.dropout_module',
#  'decoder.layers.43.self_attn',
#  'decoder.layers.43.self_attn.dropout_module',
#  'decoder.layers.43.self_attn.qkv_proj',
#  'decoder.layers.43.self_attn.out_proj',
#  'decoder.layers.43.self_attn_layer_norm',
#  'decoder.layers.43.fc1',
#  'decoder.layers.43.fc2',
#  'decoder.layers.43.final_layer_norm',
#  'decoder.layers.44',
#  'decoder.layers.44.dropout_module',
#  'decoder.layers.44.self_attn',
#  'decoder.layers.44.self_attn.dropout_module',
#  'decoder.layers.44.self_attn.qkv_proj',
#  'decoder.layers.44.self_attn.out_proj',
#  'decoder.layers.44.self_attn_layer_norm',
#  'decoder.layers.44.fc1',
#  'decoder.layers.44.fc2',
#  'decoder.layers.44.final_layer_norm',
#  'decoder.layers.45',
#  'decoder.layers.45.dropout_module',
#  'decoder.layers.45.self_attn',
#  'decoder.layers.45.self_attn.dropout_module',
#  'decoder.layers.45.self_attn.qkv_proj',
#  'decoder.layers.45.self_attn.out_proj',
#  'decoder.layers.45.self_attn_layer_norm',
#  'decoder.layers.45.fc1',
#  'decoder.layers.45.fc2',
#  'decoder.layers.45.final_layer_norm',
#  'decoder.layers.46',
#  'decoder.layers.46.dropout_module',
#  'decoder.layers.46.self_attn',
#  'decoder.layers.46.self_attn.dropout_module',
#  'decoder.layers.46.self_attn.qkv_proj',
#  'decoder.layers.46.self_attn.out_proj',
#  'decoder.layers.46.self_attn_layer_norm',
#  'decoder.layers.46.fc1',
#  'decoder.layers.46.fc2',
#  'decoder.layers.46.final_layer_norm',
#  'decoder.layers.47',
#  'decoder.layers.47.dropout_module',
#  'decoder.layers.47.self_attn',
#  'decoder.layers.47.self_attn.dropout_module',
#  'decoder.layers.47.self_attn.qkv_proj',
#  'decoder.layers.47.self_attn.out_proj',
#  'decoder.layers.47.self_attn_layer_norm',
#  'decoder.layers.47.fc1',
#  'decoder.layers.47.fc2',
#  'decoder.layers.47.final_layer_norm',
#  'decoder.layers.48',
#  'decoder.layers.48.dropout_module',
#  'decoder.layers.48.self_attn',
#  'decoder.layers.48.self_attn.dropout_module',
#  'decoder.layers.48.self_attn.qkv_proj',
#  'decoder.layers.48.self_attn.out_proj',
#  'decoder.layers.48.self_attn_layer_norm',
#  'decoder.layers.48.fc1',
#  'decoder.layers.48.fc2',
#  'decoder.layers.48.final_layer_norm',
#  'decoder.layers.49',
#  'decoder.layers.49.dropout_module',
#  'decoder.layers.49.self_attn',
#  'decoder.layers.49.self_attn.dropout_module',
#  'decoder.layers.49.self_attn.qkv_proj',
#  'decoder.layers.49.self_attn.out_proj',
#  'decoder.layers.49.self_attn_layer_norm',
#  'decoder.layers.49.fc1',
#  'decoder.layers.49.fc2',
#  'decoder.layers.49.final_layer_norm',
#  'decoder.layers.50',
#  'decoder.layers.50.dropout_module',
#  'decoder.layers.50.self_attn',
#  'decoder.layers.50.self_attn.dropout_module',
#  'decoder.layers.50.self_attn.qkv_proj',
#  'decoder.layers.50.self_attn.out_proj',
#  'decoder.layers.50.self_attn_layer_norm',
#  'decoder.layers.50.fc1',
#  'decoder.layers.50.fc2',
#  'decoder.layers.50.final_layer_norm',
#  'decoder.layers.51',
#  'decoder.layers.51.dropout_module',
#  'decoder.layers.51.self_attn',
#  'decoder.layers.51.self_attn.dropout_module',
#  'decoder.layers.51.self_attn.qkv_proj',
#  'decoder.layers.51.self_attn.out_proj',
#  'decoder.layers.51.self_attn_layer_norm',
#  'decoder.layers.51.fc1',
#  'decoder.layers.51.fc2',
#  'decoder.layers.51.final_layer_norm',
#  'decoder.layers.52',
#  'decoder.layers.52.dropout_module',
#  'decoder.layers.52.self_attn',
#  'decoder.layers.52.self_attn.dropout_module',
#  'decoder.layers.52.self_attn.qkv_proj',
#  'decoder.layers.52.self_attn.out_proj',
#  'decoder.layers.52.self_attn_layer_norm',
#  'decoder.layers.52.fc1',
#  'decoder.layers.52.fc2',
#  'decoder.layers.52.final_layer_norm',
#  'decoder.layers.53',
#  'decoder.layers.53.dropout_module',
#  'decoder.layers.53.self_attn',
#  'decoder.layers.53.self_attn.dropout_module',
#  'decoder.layers.53.self_attn.qkv_proj',
#  'decoder.layers.53.self_attn.out_proj',
#  'decoder.layers.53.self_attn_layer_norm',
#  'decoder.layers.53.fc1',
#  'decoder.layers.53.fc2',
#  'decoder.layers.53.final_layer_norm',
#  'decoder.layers.54',
#  'decoder.layers.54.dropout_module',
#  'decoder.layers.54.self_attn',
#  'decoder.layers.54.self_attn.dropout_module',
#  'decoder.layers.54.self_attn.qkv_proj',
#  'decoder.layers.54.self_attn.out_proj',
#  'decoder.layers.54.self_attn_layer_norm',
#  'decoder.layers.54.fc1',
#  'decoder.layers.54.fc2',
#  'decoder.layers.54.final_layer_norm',
#  'decoder.layers.55',
#  'decoder.layers.55.dropout_module',
#  'decoder.layers.55.self_attn',
#  'decoder.layers.55.self_attn.dropout_module',
#  'decoder.layers.55.self_attn.qkv_proj',
#  'decoder.layers.55.self_attn.out_proj',
#  'decoder.layers.55.self_attn_layer_norm',
#  'decoder.layers.55.fc1',
#  'decoder.layers.55.fc2',
#  'decoder.layers.55.final_layer_norm',
#  'decoder.layers.56',
#  'decoder.layers.56.dropout_module',
#  'decoder.layers.56.self_attn',
#  'decoder.layers.56.self_attn.dropout_module',
#  'decoder.layers.56.self_attn.qkv_proj',
#  'decoder.layers.56.self_attn.out_proj',
#  'decoder.layers.56.self_attn_layer_norm',
#  'decoder.layers.56.fc1',
#  'decoder.layers.56.fc2',
#  'decoder.layers.56.final_layer_norm',
#  'decoder.layers.57',
#  'decoder.layers.57.dropout_module',
#  'decoder.layers.57.self_attn',
#  'decoder.layers.57.self_attn.dropout_module',
#  'decoder.layers.57.self_attn.qkv_proj',
#  'decoder.layers.57.self_attn.out_proj',
#  'decoder.layers.57.self_attn_layer_norm',
#  'decoder.layers.57.fc1',
#  'decoder.layers.57.fc2',
#  'decoder.layers.57.final_layer_norm',
#  'decoder.layers.58',
#  'decoder.layers.58.dropout_module',
#  'decoder.layers.58.self_attn',
#  'decoder.layers.58.self_attn.dropout_module',
#  'decoder.layers.58.self_attn.qkv_proj',
#  'decoder.layers.58.self_attn.out_proj',
#  'decoder.layers.58.self_attn_layer_norm',
#  'decoder.layers.58.fc1',
#  'decoder.layers.58.fc2',
#  'decoder.layers.58.final_layer_norm',
#  'decoder.layers.59',
#  'decoder.layers.59.dropout_module',
#  'decoder.layers.59.self_attn',
#  'decoder.layers.59.self_attn.dropout_module',
#  'decoder.layers.59.self_attn.qkv_proj',
#  'decoder.layers.59.self_attn.out_proj',
#  'decoder.layers.59.self_attn_layer_norm',
#  'decoder.layers.59.fc1',
#  'decoder.layers.59.fc2',
#  'decoder.layers.59.final_layer_norm',
#  'decoder.layers.60',
#  'decoder.layers.60.dropout_module',
#  'decoder.layers.60.self_attn',
#  'decoder.layers.60.self_attn.dropout_module',
#  'decoder.layers.60.self_attn.qkv_proj',
#  'decoder.layers.60.self_attn.out_proj',
#  'decoder.layers.60.self_attn_layer_norm',
#  'decoder.layers.60.fc1',
#  'decoder.layers.60.fc2',
#  'decoder.layers.60.final_layer_norm',
#  'decoder.layers.61',
#  'decoder.layers.61.dropout_module',
#  'decoder.layers.61.self_attn',
#  'decoder.layers.61.self_attn.dropout_module',
#  'decoder.layers.61.self_attn.qkv_proj',
#  'decoder.layers.61.self_attn.out_proj',
#  'decoder.layers.61.self_attn_layer_norm',
#  'decoder.layers.61.fc1',
#  'decoder.layers.61.fc2',
#  'decoder.layers.61.final_layer_norm',
#  'decoder.layers.62',
#  'decoder.layers.62.dropout_module',
#  'decoder.layers.62.self_attn',
#  'decoder.layers.62.self_attn.dropout_module',
#  'decoder.layers.62.self_attn.qkv_proj',
#  'decoder.layers.62.self_attn.out_proj',
#  'decoder.layers.62.self_attn_layer_norm',
#  'decoder.layers.62.fc1',
#  'decoder.layers.62.fc2',
#  'decoder.layers.62.final_layer_norm',
#  'decoder.layers.63',
#  'decoder.layers.63.dropout_module',
#  'decoder.layers.63.self_attn',
#  'decoder.layers.63.self_attn.dropout_module',
#  'decoder.layers.63.self_attn.qkv_proj',
#  'decoder.layers.63.self_attn.out_proj',
#  'decoder.layers.63.self_attn_layer_norm',
#  'decoder.layers.63.fc1',
#  'decoder.layers.63.fc2',
#  'decoder.layers.63.final_layer_norm',
#  'decoder.layers.64',
#  'decoder.layers.64.dropout_module',
#  'decoder.layers.64.self_attn',
#  'decoder.layers.64.self_attn.dropout_module',
#  'decoder.layers.64.self_attn.qkv_proj',
#  'decoder.layers.64.self_attn.out_proj',
#  'decoder.layers.64.self_attn_layer_norm',
#  'decoder.layers.64.fc1',
#  'decoder.layers.64.fc2',
#  'decoder.layers.64.final_layer_norm',
#  'decoder.layers.65',
#  'decoder.layers.65.dropout_module',
#  'decoder.layers.65.self_attn',
#  'decoder.layers.65.self_attn.dropout_module',
#  'decoder.layers.65.self_attn.qkv_proj',
#  'decoder.layers.65.self_attn.out_proj',
#  'decoder.layers.65.self_attn_layer_norm',
#  'decoder.layers.65.fc1',
#  'decoder.layers.65.fc2',
#  'decoder.layers.65.final_layer_norm',
#  'decoder.layers.66',
#  'decoder.layers.66.dropout_module',
#  'decoder.layers.66.self_attn',
#  'decoder.layers.66.self_attn.dropout_module',
#  'decoder.layers.66.self_attn.qkv_proj',
#  'decoder.layers.66.self_attn.out_proj',
#  'decoder.layers.66.self_attn_layer_norm',
#  'decoder.layers.66.fc1',
#  'decoder.layers.66.fc2',
#  'decoder.layers.66.final_layer_norm',
#  'decoder.layers.67',
#  'decoder.layers.67.dropout_module',
#  'decoder.layers.67.self_attn',
#  'decoder.layers.67.self_attn.dropout_module',
#  'decoder.layers.67.self_attn.qkv_proj',
#  'decoder.layers.67.self_attn.out_proj',
#  'decoder.layers.67.self_attn_layer_norm',
#  'decoder.layers.67.fc1',
#  'decoder.layers.67.fc2',
#  'decoder.layers.67.final_layer_norm',
#  'decoder.layers.68',
#  'decoder.layers.68.dropout_module',
#  'decoder.layers.68.self_attn',
#  'decoder.layers.68.self_attn.dropout_module',
#  'decoder.layers.68.self_attn.qkv_proj',
#  'decoder.layers.68.self_attn.out_proj',
#  'decoder.layers.68.self_attn_layer_norm',
#  'decoder.layers.68.fc1',
#  'decoder.layers.68.fc2',
#  'decoder.layers.68.final_layer_norm',
#  'decoder.layers.69',
#  'decoder.layers.69.dropout_module',
#  'decoder.layers.69.self_attn',
#  'decoder.layers.69.self_attn.dropout_module',
#  'decoder.layers.69.self_attn.qkv_proj',
#  'decoder.layers.69.self_attn.out_proj',
#  'decoder.layers.69.self_attn_layer_norm',
#  'decoder.layers.69.fc1',
#  'decoder.layers.69.fc2',
#  'decoder.layers.69.final_layer_norm',
#  'decoder.layers.70',
#  'decoder.layers.70.dropout_module',
#  'decoder.layers.70.self_attn',
#  'decoder.layers.70.self_attn.dropout_module',
#  'decoder.layers.70.self_attn.qkv_proj',
#  'decoder.layers.70.self_attn.out_proj',
#  'decoder.layers.70.self_attn_layer_norm',
#  'decoder.layers.70.fc1',
#  'decoder.layers.70.fc2',
#  'decoder.layers.70.final_layer_norm',
#  'decoder.layers.71',
#  'decoder.layers.71.dropout_module',
#  'decoder.layers.71.self_attn',
#  'decoder.layers.71.self_attn.dropout_module',
#  'decoder.layers.71.self_attn.qkv_proj',
#  'decoder.layers.71.self_attn.out_proj',
#  'decoder.layers.71.self_attn_layer_norm',
#  'decoder.layers.71.fc1',
#  'decoder.layers.71.fc2',
#  'decoder.layers.71.final_layer_norm',
#  'decoder.layers.72',
#  'decoder.layers.72.dropout_module',
#  'decoder.layers.72.self_attn',
#  'decoder.layers.72.self_attn.dropout_module',
#  'decoder.layers.72.self_attn.qkv_proj',
#  'decoder.layers.72.self_attn.out_proj',
#  'decoder.layers.72.self_attn_layer_norm',
#  'decoder.layers.72.fc1',
#  'decoder.layers.72.fc2',
#  'decoder.layers.72.final_layer_norm',
#  'decoder.layers.73',
#  'decoder.layers.73.dropout_module',
#  'decoder.layers.73.self_attn',
#  'decoder.layers.73.self_attn.dropout_module',
#  'decoder.layers.73.self_attn.qkv_proj',
#  'decoder.layers.73.self_attn.out_proj',
#  'decoder.layers.73.self_attn_layer_norm',
#  'decoder.layers.73.fc1',
#  'decoder.layers.73.fc2',
#  'decoder.layers.73.final_layer_norm',
#  'decoder.layers.74',
#  'decoder.layers.74.dropout_module',
#  'decoder.layers.74.self_attn',
#  'decoder.layers.74.self_attn.dropout_module',
#  'decoder.layers.74.self_attn.qkv_proj',
#  'decoder.layers.74.self_attn.out_proj',
#  'decoder.layers.74.self_attn_layer_norm',
#  'decoder.layers.74.fc1',
#  'decoder.layers.74.fc2',
#  'decoder.layers.74.final_layer_norm',
#  'decoder.layers.75',
#  'decoder.layers.75.dropout_module',
#  'decoder.layers.75.self_attn',
#  'decoder.layers.75.self_attn.dropout_module',
#  'decoder.layers.75.self_attn.qkv_proj',
#  'decoder.layers.75.self_attn.out_proj',
#  'decoder.layers.75.self_attn_layer_norm',
#  'decoder.layers.75.fc1',
#  'decoder.layers.75.fc2',
#  'decoder.layers.75.final_layer_norm',
#  'decoder.layers.76',
#  'decoder.layers.76.dropout_module',
#  'decoder.layers.76.self_attn',
#  'decoder.layers.76.self_attn.dropout_module',
#  'decoder.layers.76.self_attn.qkv_proj',
#  'decoder.layers.76.self_attn.out_proj',
#  'decoder.layers.76.self_attn_layer_norm',
#  'decoder.layers.76.fc1',
#  'decoder.layers.76.fc2',
#  'decoder.layers.76.final_layer_norm',
#  'decoder.layers.77',
#  'decoder.layers.77.dropout_module',
#  'decoder.layers.77.self_attn',
#  'decoder.layers.77.self_attn.dropout_module',
#  'decoder.layers.77.self_attn.qkv_proj',
#  'decoder.layers.77.self_attn.out_proj',
#  'decoder.layers.77.self_attn_layer_norm',
#  'decoder.layers.77.fc1',
#  'decoder.layers.77.fc2',
#  'decoder.layers.77.final_layer_norm',
#  'decoder.layers.78',
#  'decoder.layers.78.dropout_module',
#  'decoder.layers.78.self_attn',
#  'decoder.layers.78.self_attn.dropout_module',
#  'decoder.layers.78.self_attn.qkv_proj',
#  'decoder.layers.78.self_attn.out_proj',
#  'decoder.layers.78.self_attn_layer_norm',
#  'decoder.layers.78.fc1',
#  'decoder.layers.78.fc2',
#  'decoder.layers.78.final_layer_norm',
#  'decoder.layers.79',
#  'decoder.layers.79.dropout_module',
#  'decoder.layers.79.self_attn',
#  'decoder.layers.79.self_attn.dropout_module',
#  'decoder.layers.79.self_attn.qkv_proj',
#  'decoder.layers.79.self_attn.out_proj',
#  'decoder.layers.79.self_attn_layer_norm',
#  'decoder.layers.79.fc1',
#  'decoder.layers.79.fc2',
#  'decoder.layers.79.final_layer_norm',
#  'decoder.layers.80',
#  'decoder.layers.80.dropout_module',
#  'decoder.layers.80.self_attn',
#  'decoder.layers.80.self_attn.dropout_module',
#  'decoder.layers.80.self_attn.qkv_proj',
#  'decoder.layers.80.self_attn.out_proj',
#  'decoder.layers.80.self_attn_layer_norm',
#  'decoder.layers.80.fc1',
#  'decoder.layers.80.fc2',
#  'decoder.layers.80.final_layer_norm',
#  'decoder.layers.81',
#  'decoder.layers.81.dropout_module',
#  'decoder.layers.81.self_attn',
#  'decoder.layers.81.self_attn.dropout_module',
#  'decoder.layers.81.self_attn.qkv_proj',
#  'decoder.layers.81.self_attn.out_proj',
#  'decoder.layers.81.self_attn_layer_norm',
#  'decoder.layers.81.fc1',
#  'decoder.layers.81.fc2',
#  'decoder.layers.81.final_layer_norm',
#  'decoder.layers.82',
#  'decoder.layers.82.dropout_module',
#  'decoder.layers.82.self_attn',
#  'decoder.layers.82.self_attn.dropout_module',
#  'decoder.layers.82.self_attn.qkv_proj',
#  'decoder.layers.82.self_attn.out_proj',
#  'decoder.layers.82.self_attn_layer_norm',
#  'decoder.layers.82.fc1',
#  'decoder.layers.82.fc2',
#  'decoder.layers.82.final_layer_norm',
#  'decoder.layers.83',
#  'decoder.layers.83.dropout_module',
#  'decoder.layers.83.self_attn',
#  'decoder.layers.83.self_attn.dropout_module',
#  'decoder.layers.83.self_attn.qkv_proj',
#  'decoder.layers.83.self_attn.out_proj',
#  'decoder.layers.83.self_attn_layer_norm',
#  'decoder.layers.83.fc1',
#  'decoder.layers.83.fc2',
#  'decoder.layers.83.final_layer_norm',
#  'decoder.layers.84',
#  'decoder.layers.84.dropout_module',
#  'decoder.layers.84.self_attn',
#  'decoder.layers.84.self_attn.dropout_module',
#  'decoder.layers.84.self_attn.qkv_proj',
#  'decoder.layers.84.self_attn.out_proj',
#  'decoder.layers.84.self_attn_layer_norm',
#  'decoder.layers.84.fc1',
#  'decoder.layers.84.fc2',
#  'decoder.layers.84.final_layer_norm',
#  'decoder.layers.85',
#  'decoder.layers.85.dropout_module',
#  'decoder.layers.85.self_attn',
#  'decoder.layers.85.self_attn.dropout_module',
#  'decoder.layers.85.self_attn.qkv_proj',
#  'decoder.layers.85.self_attn.out_proj',
#  'decoder.layers.85.self_attn_layer_norm',
#  'decoder.layers.85.fc1',
#  'decoder.layers.85.fc2',
#  'decoder.layers.85.final_layer_norm',
#  'decoder.layers.86',
#  'decoder.layers.86.dropout_module',
#  'decoder.layers.86.self_attn',
#  'decoder.layers.86.self_attn.dropout_module',
#  'decoder.layers.86.self_attn.qkv_proj',
#  'decoder.layers.86.self_attn.out_proj',
#  'decoder.layers.86.self_attn_layer_norm',
#  'decoder.layers.86.fc1',
#  'decoder.layers.86.fc2',
#  'decoder.layers.86.final_layer_norm',
#  'decoder.layers.87',
#  'decoder.layers.87.dropout_module',
#  'decoder.layers.87.self_attn',
#  'decoder.layers.87.self_attn.dropout_module',
#  'decoder.layers.87.self_attn.qkv_proj',
#  'decoder.layers.87.self_attn.out_proj',
#  'decoder.layers.87.self_attn_layer_norm',
#  'decoder.layers.87.fc1',
#  'decoder.layers.87.fc2',
#  'decoder.layers.87.final_layer_norm',
#  'decoder.layers.88',
#  'decoder.layers.88.dropout_module',
#  'decoder.layers.88.self_attn',
#  'decoder.layers.88.self_attn.dropout_module',
#  'decoder.layers.88.self_attn.qkv_proj',
#  'decoder.layers.88.self_attn.out_proj',
#  'decoder.layers.88.self_attn_layer_norm',
#  'decoder.layers.88.fc1',
#  'decoder.layers.88.fc2',
#  'decoder.layers.88.final_layer_norm',
#  'decoder.layers.89',
#  'decoder.layers.89.dropout_module',
#  'decoder.layers.89.self_attn',
#  'decoder.layers.89.self_attn.dropout_module',
#  'decoder.layers.89.self_attn.qkv_proj',
#  'decoder.layers.89.self_attn.out_proj',
#  'decoder.layers.89.self_attn_layer_norm',
#  'decoder.layers.89.fc1',
#  'decoder.layers.89.fc2',
#  'decoder.layers.89.final_layer_norm',
#  'decoder.layers.90',
#  'decoder.layers.90.dropout_module',
#  'decoder.layers.90.self_attn',
#  'decoder.layers.90.self_attn.dropout_module',
#  'decoder.layers.90.self_attn.qkv_proj',
#  'decoder.layers.90.self_attn.out_proj',
#  'decoder.layers.90.self_attn_layer_norm',
#  'decoder.layers.90.fc1',
#  'decoder.layers.90.fc2',
#  'decoder.layers.90.final_layer_norm',
#  'decoder.layers.91',
#  'decoder.layers.91.dropout_module',
#  'decoder.layers.91.self_attn',
#  'decoder.layers.91.self_attn.dropout_module',
#  'decoder.layers.91.self_attn.qkv_proj',
#  'decoder.layers.91.self_attn.out_proj',
#  'decoder.layers.91.self_attn_layer_norm',
#  'decoder.layers.91.fc1',
#  'decoder.layers.91.fc2',
#  'decoder.layers.91.final_layer_norm',
#  'decoder.layers.92',
#  'decoder.layers.92.dropout_module',
#  'decoder.layers.92.self_attn',
#  'decoder.layers.92.self_attn.dropout_module',
#  'decoder.layers.92.self_attn.qkv_proj',
#  'decoder.layers.92.self_attn.out_proj',
#  'decoder.layers.92.self_attn_layer_norm',
#  'decoder.layers.92.fc1',
#  'decoder.layers.92.fc2',
#  'decoder.layers.92.final_layer_norm',
#  'decoder.layers.93',
#  'decoder.layers.93.dropout_module',
#  'decoder.layers.93.self_attn',
#  'decoder.layers.93.self_attn.dropout_module',
#  'decoder.layers.93.self_attn.qkv_proj',
#  'decoder.layers.93.self_attn.out_proj',
#  'decoder.layers.93.self_attn_layer_norm',
#  'decoder.layers.93.fc1',
#  'decoder.layers.93.fc2',
#  'decoder.layers.93.final_layer_norm',
#  'decoder.layers.94',
#  'decoder.layers.94.dropout_module',
#  'decoder.layers.94.self_attn',
#  'decoder.layers.94.self_attn.dropout_module',
#  'decoder.layers.94.self_attn.qkv_proj',
#  'decoder.layers.94.self_attn.out_proj',
#  'decoder.layers.94.self_attn_layer_norm',
#  'decoder.layers.94.fc1',
#  'decoder.layers.94.fc2',
#  'decoder.layers.94.final_layer_norm',
#  'decoder.layers.95',
#  'decoder.layers.95.dropout_module',
#  'decoder.layers.95.self_attn',
#  'decoder.layers.95.self_attn.dropout_module',
#  'decoder.layers.95.self_attn.qkv_proj',
#  'decoder.layers.95.self_attn.out_proj',
#  'decoder.layers.95.self_attn_layer_norm',
#  'decoder.layers.95.fc1',
#  'decoder.layers.95.fc2',
#  'decoder.layers.95.final_layer_norm',
#  'decoder.layer_norm',
#  'decoder.output_projection']

# %% [markdown]
# We can select the module names of interest and pass them into a ``get_activations`` function alongside our set of prompts.

# %%
module_names = ['decoder.layers.0']

response = opt_model.get_activations(prompt, module_names)

print("Prompt: ", prompt)
print("Activations: ", response.activations)
# Out:
# Prompt:  Hello World
# Activations:  [{'decoder.layers.0': tensor([[ 1.2041, -0.0936,  0.0403,  ..., -0.5361,  0.4006,  0.6240],
#         [ 0.1639, -0.4377, -0.4321,  ..., -0.2380,  0.0721,  0.8525]],
#        dtype=torch.float16)}]

# %% [markdown]
# Module activations are returned as torch tensors. We can access them through the activations object:

# %%
response.activations[0]['decoder.layers.0']
# Out:
# tensor([[ 1.2041, -0.0936,  0.0403,  ..., -0.5361,  0.4006,  0.6240],
#         [ 0.1639, -0.4377, -0.4321,  ..., -0.2380,  0.0721,  0.8525]],
#        dtype=torch.float16)

# %%
response.activations[0]['decoder.layers.0'].shape
# Out:
# torch.Size([2, 12288])
